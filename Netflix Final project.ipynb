# %% [markdown]
# # 🎬 Netflix Movies & TV Shows – Data Analysis Project

# %% [markdown]
# ## ⭐ 1. Project Summary

# %% [markdown]
# ### 📄 Description:
# ##### This project performs a complete data analysis on the Netflix Movies and TV Shows dataset.
# ##### which contains information about Netflix movies and series, has 12 columns, including some null values.
# ##### The analysis was carried out with the Pandas, Matplotlib and Seaborn libraries, which were used to treat, process and visualize the information.
# ##### It includes data cleaning, exploration, and visual insights to understand Netflix’s content distribution, genres, ratings, and growth patterns. The goal is to convert raw data into meaningful insights using Python.

# %% [markdown]
# ### 📊Column Description:
#
# | Column Name     | Description |
# |-----------------|-------------|
# | show_id         | Unique identifier for each title in the Netflix catalog |
# | type            | The type of content: either "Movie" or "TV Show" |
# | title           | Name of the movie or TV show |
# | director        | Name(s) of the director(s), May be missing (i.e., NaN) |
# | cast            |Names of the cast members, Can also be missing for some entries |
# | country         | The country (or countries) where the content was produced |
# | date_added      | The date the title was added to Netflix|
# | release_year    | The year the movie/show was originally released |
# | rating          | Maturity rating (e.g., "TV-MA", "PG-13", "G", etc.)|
# | duration        | Duration in minutes (Movies) or number of seasons (TV Shows) |
# | listed_in       | Genre/category the title belongs to |
# | description     | Short summary of the content |

# %% [markdown]
# ## ❗ 2. Problem Statement

# %% [markdown]
# ### 🧩 Description:
# ##### Netflix has thousands of movies and TV shows from different countries and genres.However, the dataset is messy and hard to analyze directly.
# ##### The key problem is: How can we clean, analyze, and visualize the data to uncover patterns about Netflix content?
# ##### This project solves that problem by performing structured data analysis.

# %% [markdown]
# ## 🎯 3. Project Objectives
#
# ### 🎯 Description:
# #### The project aims to:
# 	•	Clean and preprocess data.
# 	•	Explore trends in movies vs. TV shows, genres, countries, and ratings.
# 	•	Visualize insights through charts and graphs.
# 	•	Provide data-driven recommendations for content strategy.
# ##### These objectives help understand how Netflix builds its content library.

# %% [markdown]
# ## 🛠 4. Setup & Configuration
#
# ### ⚙ Description:
# ##### Setting up the environment is essential to run the project smoothly.
#
# #### Requirements:
# 	•	Python 3.8+
# 	•	Jupyter Notebook / VS Code / Google Colab
#
# #### Install libraries:

# %%
pip install pandas numpy matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Import in python:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ### Load dataset:

# %%
df=pd.read_csv(r"D:\Python\Python\netflix_movies (1).csv")

# %% [markdown]
# ## 🧹 5. Data Cleaning
#
# ### 🧽 Description:
# ##### The raw dataset contains missing values, duplicates, and unstructured columns.
# ##### This step makes the data usable for analysis.

# %% [markdown]
# ### head(): Shows the first few rows

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### tail(): Shows the last few rows

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# ### sample():Shows random row

# %%
df.sample()
# Out:
#      show_id   type           title            director  \
# 3107   s3108  Movie  Jacob's Ladder  David M. Rosenthal
#
#                                                    cast        country  \
# 3107  Michael Ealy, Jesse Williams, Nicole Beharie, ...  United States
#
#              date_added  release_year rating duration  listed_in  \
# 3107  December 22, 2019          2019      R   90 min  Thrillers
#
#                                             description
# 3107  After being reunited with a brother he thought...

# %% [markdown]
# ### info():Summary of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### nunique():Count unique values

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8804
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# ### describe():Summary for numeric columns

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include='object')
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8804           4528                7692
# top      s8807  Movie  15-Aug  Rajiv Chilaka  David Attenborough
# freq         1   6131       2             19                  19
#
#               country       date_added rating  duration  \
# count            7976             8797   8803      8804
# unique            748             1767     17       220
# top     United States  January 1, 2020  TV-MA  1 Season
# freq             2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# ...

# %% [markdown]
# ### shape:Dimensions of a df

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# ### isna().sum():Count the number of missing values

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### duplicate().sum():Count duplicate rows

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### fillna():Fill missing values with a constant

# %%
df['director']=df['director'].fillna('Not Available')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Not Available
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Not Available
# 4         s5  TV Show           Kota Factory    Not Available
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb    Not Available
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### dropna():Remove missing values

# %%
df.dropna(inplace=True)
df
# Out:
#      show_id     type                          title         director  \
# 1         s2  TV Show                  Blood & Water    Not Available
# 4         s5  TV Show                   Kota Factory    Not Available
# 7         s8    Movie                        Sankofa     Haile Gerima
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9        s10    Movie                   The Starling   Theodore Melfi
# ...      ...      ...                            ...              ...
# 8801   s8802    Movie                        Zinzana  Majid Al Ansari
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
# 8806   s8807    Movie                         Zubaan      Mozez Singh
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
## Conversion of duration columns dtypes to datatime dtypes and splitting the year,month and date columns.
df['date'] = pd.to_datetime(df['date_added'], errors='coerce')
df['day'] = df['date'].dt.day
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# Drop original columns
df.drop(['date_added','date'], axis=1, inplace=True)

df.head()
# Out:
#   show_id     type                          title         director  \
# 1      s2  TV Show                  Blood & Water    Not Available
# 4      s5  TV Show                   Kota Factory    Not Available
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9     s10    Movie                   The Starling   Theodore Melfi
#
#                                                 cast  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country  release_year rating  \
# 1                                       South Africa          2021  TV-MA
# 4                                              India          2021  TV-MA
# ...

# %%
df.isna().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# day             77
# month           77
# year            77
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#      show_id     type                          title         director  \
# 1         s2  TV Show                  Blood & Water    Not Available
# 4         s5  TV Show                   Kota Factory    Not Available
# 7         s8    Movie                        Sankofa     Haile Gerima
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9        s10    Movie                   The Starling   Theodore Melfi
# ...      ...      ...                            ...              ...
# 8801   s8802    Movie                        Zinzana  Majid Al Ansari
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
# 8806   s8807    Movie                         Zubaan      Mozez Singh
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
df.sample(10)
# Out:
#      show_id     type                                title  \
# 1355   s1356  TV Show                           Love Daily
# 2588   s2589  TV Show                              Oh Yuck
# 3522   s3523    Movie                    Shanghai Fortress
# 5861   s5862    Movie                Pee-wee's Big Holiday
# 2380   s2381    Movie                         Riding Faith
# 3527   s3528  TV Show                  The Mind, Explained
# 4138   s4139    Movie  Lego DC Comics: Batman Be-Leaguered
# 8285   s8286    Movie  The Dukes of Hazzard: The Beginning
# 59       s60    Movie          Naruto Shippuden: The Movie
# 460     s461    Movie                            Surf's Up
#
#                      director  \
# 1355            Not Available
# 2588            Not Available
# 3522              Teng Huatao
# 5861                 John Lee
# 2380             Paco Aguilar
# 3527            Not Available
# 4138             Rick Morales
# 8285         Robert Berlinger
# 59            Hajime Kamegaki
# ...

# %% [markdown]
# ## 📊 6. Exploratory Data Analysis (EDA)
#
# ### 📈 Description:
# ##### Visual analysis is performed to answer key questions:

# %% [markdown]
# ### value_counts():Count unique values

# %%
## count of content by type(Movies/TV Shows)
df['type'].value_counts()
# Out:
# type
# Movie      5277
# TV Show    1936
# Name: count, dtype: int64

# %%
## count ofcontent by rating
df['rating'].value_counts()
# Out:
# rating
# TV-MA       2636
# TV-14       1734
# R            779
# TV-PG        633
# PG-13        470
# PG           275
# TV-Y7        220
# TV-Y         203
# TV-G         153
# NR            61
# G             40
# NC-17          3
# TV-Y7-FV       3
# UR             3
# Name: count, dtype: int64

# %% [markdown]
# ### groupby():Aggregate by one/more columns

# %%
## Most content released by country
df.groupby('country')['title'].count().sort_values(ascending=False).head()
# Out:
# country
# United States     2449
# India              939
# United Kingdom     335
# Japan              236
# South Korea        192
# Name: title, dtype: int64

# %%
## Average duration of movies(if duration numeric)
df.groupby('type')['duration'].describe()
# Out:
#         count unique       top  freq
# type
# Movie    5277    191    94 min   136
# TV Show  1936     14  1 Season  1250

# %% [markdown]
# ### orderby(sorting):Order data

# %%
## Top countries with highest netflix content
df['country'].value_counts().head(10)
# Out:
# country
# United States     2449
# India              939
# United Kingdom     335
# Japan              236
# South Korea        192
# Canada             155
# Spain              123
# France             106
# Egypt              105
# Turkey             105
# Name: count, dtype: int64

# %% [markdown]
# ### agg():Apply multiple functions

# %%
# Finding range of the dataset

starting_range = df['release_year'].min()
ending_range = df['release_year'].max()
print(f"The dataset ranges from {starting_range} to {ending_range}")
# Out:
# The dataset ranges from 1942 to 2021

# %%
## Average duration of movies?

movie_durations = df.loc[df['type'] == 'Movie']['duration'].str.replace(' min','').astype(float).reset_index(drop=True)
average_duration = movie_durations.mean()
print(f"Average movie duration: {average_duration:.2f} minutes")
# Out:
# Average movie duration: 102.14 minutes

# %% [markdown]
# ### isin():

# %%
## To show all records of a particular item in any column
df[df['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title       director  \
# 1059   s1060  TV Show  House of Cards  Not Available
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#       release_year rating   duration                listed_in  \
# 1059          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description   day  month    year
# 1059  A ruthless politician will stop at nothing to ...  14.0    4.0  2021.0

# %% [markdown]
# ### str.contains():

# %%
## To show all records of a particular string in any column
df[df['cast'].str.contains('Salman Khan')]
# Out:
#      show_id   type                                     title  \
# 1441   s1442  Movie                             Hello Brother
# 1674   s1675  Movie                                 Bodyguard
# 2339   s2340  Movie                      Prem Ratan Dhan Payo
# 2545   s2546  Movie                           Andaz Apna Apna
# 2734   s2735  Movie                        Kuch Kuch Hota Hai
# 2756   s2757  Movie                                 Paharganj
# 2957   s2958  Movie                       Hum Aapke Hain Koun
# 2969   s2970  Movie                     Together For Eternity
# 4729   s4730  Movie                     Main aurr Mrs. Khanna
# 5718   s5719  Movie                           Mumbai Cha Raja
# 6440   s6441  Movie                            Chal Mere Bhai
# 7022   s7023  Movie                      Hum Saath-Saath Hain
# 7109   s7110  Movie  Jaan-E-Mann: Let's Fall in Love... Again
# 7144   s7145  Movie                                    Judwaa
# ...

# %%
## salman,shah rukh, and akshay kumar movies
actors = ['Salman Khan', 'Shah Rukh Khan', 'Akshay Kumar']
df[df['cast'].str.contains('|'.join(actors), na=False) & (df['type']=='Movie')]
# Out:
#      show_id   type                                title  \
# 114     s115  Movie                               Anjaam
# 209     s210  Movie  Once Upon a Time in Mumbai Dobaara!
# 301     s302  Movie                      Chennai Express
# 1305   s1306  Movie                 Awara Paagal Deewana
# 1441   s1442  Movie                        Hello Brother
# ...      ...    ...                                  ...
# 7910   s7911  Movie                               Rustom
# 7994   s7995  Movie                    Shakti: The Power
# 8161   s8162  Movie                       Tees Maar Khan
# 8504   s8505  Movie                        The Shaukeens
# 8629   s8630  Movie                             Trimurti
#
#                      director  \
# 114              Rahul Rawail
# 209             Milan Luthria
# 301              Rohit Shetty
# 1305             Vikram Bhatt
# 1441              Sohail Khan
# ...                       ...
# 7910  Dharmendra Suresh Desai
# ...

# %% [markdown]
# ### pivot_table():Summarize with rows and columns

# %%
# Number of movies and TV shows per country
pivot = pd.pivot_table(df, index='country', columns='type', values='title', aggfunc='count', fill_value=0)
pivot.head(10)
# Out:
# type                                                Movie  TV Show
# country
# , France, Algeria                                       1        0
# , South Korea                                           0        1
# Argentina                                              34       17
# Argentina, Brazil, France, Poland, Germany, Den...      1        0
# Argentina, Chile                                        2        0
# Argentina, Chile, Peru                                  1        0
# Argentina, France                                       1        0
# Argentina, France, United States, Germany, Qatar        1        0
# Argentina, Spain                                        7        1
# Argentina, United States                                1        0

# %% [markdown]
# ### corr():Find relationships

# %%
## correlation between movie duration and release year

df_Movie=df[df['type']=='Movie'].copy()
df_Movie['duration']=df_Movie['duration'].str.replace('min', '').astype(int)
df_Movie[['duration','release_year']].corr()
# Out:
#               duration  release_year
# duration      1.000000     -0.212585
# release_year -0.212585      1.000000

# %%
df[['release_year','year']].corr()
# Out:
#               release_year      year
# release_year      1.000000  0.072412
# year              0.072412  1.000000

# %% [markdown]
# ## 📌1.Univariate Data Visualization

# %%
## 1.Which type of content is more prevalent on the platform: Movies or TV Show?


plt.figure(figsize =(5,5))
type_counts = df['type'].value_counts()
plt.pie(type_counts,labels = type_counts.index,autopct='%1.1f%%', startangle=90)
plt.title('Movies vs TV Show Distribution')
plt.show()

type_counts
# Out:
# type
# Movie      5277
# TV Show    1936
# Name: count, dtype: int64

# %% [markdown]
# #### Insight:
#     •	Movies dominate the Netflix catalog, making up 73.2% of all content, while TV Shows account for 26.8%.
# 	•	Indicates Netflix prioritizes films for casual viewing, but maintains a significant TV Show library for binge-watchers.
# 	•	Shows the platform’s content strategy: balancing quick-view movies with longer-form series.
# 	•	Strategic takeaway: Netflix could consider expanding TV Shows to enhance long-form engagement or continue emphasizing movies to cater to casual viewers.

# %%
## 2.Top 10 Directors by Number of Titles


df_net = df[df['director'] != 'Not Available']
top_directors = df_net['director'].value_counts().head(10)
sns.barplot(y=top_directors.index, x=top_directors.values,palette='Paired')
plt.title('Top 10 Directors by Number of Titles')
plt.show()
top_directors
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Name: count, dtype: int64

# %% [markdown]
# #### Insight:
#     •	A few prolific directors contribute a significant portion of Netflix content.
# 	•	Raúl Campos and Jan Suter lead with 18 titles, followed by Marcus Raboy (15) and Jay Karas (14).
# 	•	Directors like Steven Spielberg and Martin Scorsese also appear, showing a mix of international and renowned filmmakers.
# 	•	Netflix relies on repeat collaborations with these directors to maintain a consistent volume and quality of content.
# 	•	Strategic takeaway: Focusing on key directors can help Netflix curate popular content, plan marketing strategies, and negotiate future projects.

# %%
## 3.Which countries produce the most content?¶

top_country = df['country'].value_counts().head(10)
sns.barplot(y = top_country.index ,x = top_country.values, palette='Set2' )
plt.title('Top 10 Country Created Content')
plt.tight_layout()
plt.show()
top_country
# Out:
# country
# United States     2449
# India              939
# United Kingdom     335
# Japan              236
# South Korea        192
# Canada             155
# Spain              123
# France             106
# Egypt              105
# Turkey             105
# Name: count, dtype: int64

# %% [markdown]
# #### Insight:
#     •	The United States (2449 titles) and India (939 titles) are the top content-producing countries.
# 	•	Other notable contributors include United Kingdom, Japan, and South Korea.
# 	•	Reflects Netflix’s global strategy and focus on regional content.
# 	•	Strategic takeaway: Understanding production hubs helps guide licensing, localization, and market targeting.

# %%
## 4.Distribution of movie duration

plt.figure(figsize=(10,6))
plt.title("Distribution of Movie Durations (Minutes)")
sns.histplot(movie_durations, bins=40, kde=False, color="skyblue")
plt.ylabel("Number of movies")
plt.xlabel("Duration (Minutes)")
plt.show()

# %% [markdown]
# #### Insight:
#     •	Average movie duration is typically around 90–110 minutes.
# 	•	Majority of movies fall between 80–120 minutes, with very few below 60 or above 180 minutes.
# 	•	Suggests Netflix focuses on standard-length films suitable for casual viewing.
# 	•	Duration analysis helps understand viewer engagement and content pacing.

# %%
## 5.What are the most common ratings for movies and TV shows?

plt.figure(figsize=(7,5))
rating_order = df['rating'].value_counts().index
sns.countplot(x='rating', data=df , order = rating_order,palette='Set1')
plt.xticks(rotation=45)
plt.title('Distribution of Content Ratings on Netflix')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight:
# 	•	TV-MA, TV-14, and TV-PG are often the most common ratings.
# 	•	Indicates Netflix targets adult and teen audiences more than children.
# 	•	For children’s content, ratings like G or TV-G appear less frequently.
# 	•	Shows content suitability strategy for different age groups.

# %% [markdown]
# ## 📌2.Bivariate Data Visualization

# %%
## 1.What are the most common content ratings for each type of content (movies and TV shows)?

plt.figure(figsize=(8, 5))
sns.countplot(x='rating', hue='type', data=df)
plt.title('Content Type vs. Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Insight:
#     •	TV-MA, TV-14, and PG-13 are the most common ratings across Netflix content.
# 	•	Movies and TV Shows primarily target adult and teen audiences, with less content for children (G, TV-Y).
# 	•	Shows Netflix’s content suitability strategy for different age groups.
# 	•	Strategic takeaway: Helps guide audience targeting, parental guidance, and content recommendations.

# %%
## 2.Movies vs TV Shows Over the Years

type_year = df.groupby(['release_year', 'type']).size().unstack().sort_index()
plt.figure(figsize=(6, 4))
type_year.plot(kind='line', marker='o', linewidth=2, figsize=(12, 6), color=['red', 'green'])
plt.title('Number of Movies vs TV Shows Released Over the Years', fontsize=14)
plt.xlabel('Release Year', fontsize=12)
plt.ylabel('Number of Titles', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(rotation=45)
plt.legend(title='Content Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight:
#     •	Movies consistently outnumber TV Shows across most release years.
# 	•	Both content types show gradual growth, with occasional spikes in certain years.
# 	•	Indicates Netflix’s focus on movies for casual viewers, while steadily expanding TV Shows for binge-watchers.
# 	•	Strategic takeaway: Understanding yearly trends helps Netflix plan acquisitions and content strategy.

# %%
## 3.Correlation between two numeric columns

corr_data = df[['release_year','year']]
correlation = corr_data.corr()
print("Correlation between release_year and year:")
print(correlation)
plt.figure(figsize=(5,4))
sns.heatmap(correlation, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation: Release Year vs Year Added')
plt.show()
# Out:
# Correlation between release_year and year:
#               release_year      year
# release_year      1.000000  0.072412
# year              0.072412  1.000000

# %% [markdown]
# #### Insight:
#     •  	Correlation between release year and year added is very weak (0.072).
# 	•	Indicates Netflix adds both old and new content, not strictly based on release year.
# 	•	Shows content addition is influenced more by licensing and demand than by release recency.

# %%
## 4.Top 10 Countries vs. Type (Movie/TV Show)

top_10_countries = df['country'].value_counts().head(10).index
df_top_countries = df[df['country'].isin(top_10_countries)]
plt.figure(figsize=(10, 5))
sns.countplot(x='country', hue='type', data=df_top_countries,order = top_10_countries)
plt.title('Top 10 Countries vs. Type (Movie/TV Show)')
plt.xticks(rotation=45)
plt.xlabel('Country')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight:
#     •	United States, India, and United Kingdom lead content production among the top 10 countries.
# 	•	Both Movies and TV Shows are produced, though some countries focus more on one type.
# 	•	Reflects Netflix’s global expansion and regional content strategy.
# 	•	Strategic takeaway: Identifying top producing countries helps guide licensing, localization, and market targeting.

# %%
## 5.Are TV shows added in different years compared to movies?


plt.figure(figsize=(14, 6))
sns.countplot(x='year', hue='type', data=df,palette='Set1')
plt.title('Number of Movies and TV Shows per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight:
#     •	Movies are generally added in larger numbers than TV Shows each year.
# 	•	TV Shows tend to show slower, steady growth compared to movies, which may have spikes in certain years.
# 	•	Shows Netflix’s content addition strategy: prioritizing movies for casual viewing while gradually expanding TV Shows for binge-watchers.
# 	•	Helps understand temporal trends in library growth and content acquisition strategy.

# %%
## 6.Top 10 Directors vs. Type (Movie/TV Show)


top_10_directors = df_net['director'].value_counts().head(10).index
df_top_directors = df_net[df['director'].isin(top_10_directors)]
plt.figure(figsize=(10, 6))
sns.countplot(x='director', hue='type', data=df_top_directors, order = top_10_directors )
plt.title('Top 10 Directors vs. Type (Movie/TV Show)')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\rishw\AppData\Local\Temp\ipykernel_23884\2158383944.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_top_directors = df_net[df['director'].isin(top_10_directors)]

# %% [markdown]
# #### Insight:
#     •	Raúl Campos, Jan Suter, and Marcus Raboy are the top 3 directors on Netflix.
# 	•	They produce both Movies and TV Shows, contributing a significant portion of content.
# 	•	Highlights key creators driving production trends and platform engagement.
# 	•	Strategic takeaway: Collaborations with these directors help maintain consistent content volume and quality.

# %% [markdown]
# ## 📌3.Multivariate Data Visualization

# %%
## 1.Rating–Type–Year Trend Analysis

plt.figure(figsize=(12, 6))
rating_year = df.groupby(['release_year', 'type', 'rating']).size().reset_index(name='count')
sns.lineplot(
    data=rating_year,
    x='release_year',
    y='count',
    hue='rating',
    style='type'
)
plt.title('Rating vs Release Year vs Type')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight:
# 	•	TV-MA and TV-14 consistently dominate both movies and TV shows across all years.
# 	•	TV shows have a sharper rise in adult ratings after 2015, indicating a shift to mature content.
# 	•	Movies show more variability in ratings, while TV shows remain concentrated in a few top ratings.
# 	•	Child-friendly ratings (G, TV-Y) barely grow over time.

# %%
## 2.Genre × Country × Type (Top 10 Countries) Distribution Analysis

top_countries = df['country'].value_counts().head(10).index
df_country = df[df['country'].isin(top_countries)]

genre_country = df_country.groupby(['country', 'type', 'listed_in']).size().reset_index(name='count')

plt.figure(figsize=(14, 6))
sns.barplot(
    data=genre_country,
    x='country',
    y='count',
    hue='type'
)

plt.title('Genre × Country × Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight:
#
# 	•	The U.S. contributes the widest variety of genres across both movies and shows.
# 	•	India produces more movies than TV shows, heavily focused on dramas and comedies.
# 	•	Countries like Japan, South Korea, France show stronger contributions in TV shows compared to movies.
# 	•	“International TV Shows” and “International Movies” appear across many top countries, showing global diversification.

# %%
## 3.Country × Type × Rating Matrix

top_countries = df['country'].value_counts().head(10).index
df_cc = df[df['country'].isin(top_countries)]

country_rating = df_cc.groupby(['country', 'type', 'rating']).size().reset_index(name='count')

plt.figure(figsize=(14, 6))
sns.scatterplot(
    data=country_rating,
    x='country',
    y='rating',
    size='count',
    hue='type',
    sizes=(20, 300)
)

plt.title('Country × Rating × Type Distribution')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight:
#     •	U.S. titles cover almost every rating category, showing the highest diversity.
# 	•	India and the UK lean more towards adult ratings like TV-MA and TV-14.
# 	•	Child-safe ratings (G, TV-Y) are mostly from U.S., Japan, and Canada.
# 	•	TV-MA is the leading rating in almost all top countries, showing global preference for mature content.

# %%
## 4.Release Year–Duration–Rating Study (Movies)


df_movie = df[df['type'] == 'Movie'].copy()
df_movie['duration_min'] = df_movie['duration'].str.replace(' min', '').astype(int)

plt.figure(figsize=(12, 6))
sns.scatterplot(
    data=df_movie,
    x='release_year',
    y='duration_min',
    hue='rating',
    size='duration_min',
    sizes=(20, 300)
)

plt.title('Movie Duration vs Release Year vs Rating')
plt.xlabel('Release Year')
plt.ylabel('Duration (minutes)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight:
#     •	Newer movies (post-2010) show more consistent duration around 90–120 minutes.
# 	•	Older movies vary widely in duration, from very short (<70 min) to very long (>150 min).
# 	•	Higher ratings (R, TV-MA) tend to have slightly longer runtimes.
# 	•	Kids-rated movies (G, PG) cluster around shorter durations.

# %% [markdown]
# ## 🔍 7.Insights
#     •	Movies dominate Netflix (73%), while TV Shows make up 27%.
# 	•	TV-MA, TV-14, and R are the most common ratings → strong focus on adult/teen audiences.
# 	•	USA and India produce the highest number of titles.
# 	•	Top directors like Raúl Campos, Jan Suter, and Marcus Raboy contribute multiple titles.
# 	•	Average movie duration ≈ 102 minutes, mostly between 80–120 minutes.
# 	•	Movies are added more frequently each year than TV shows.
# 	•	Very weak correlation (0.072) between release year and year added → Netflix adds both old and new content.

# %% [markdown]
# ## 📝 8.Conclusion
# Netflix’s library is dominated by movies, supported by a diverse range of TV shows.
# The U.S. and India contribute the most content, and the platform mainly targets mature audiences with ratings like TV-MA and TV-14.
# The weak correlation between release year and addition year shows that Netflix adds both old and new titles based on demand, licensing, and regional strategy.
# Overall, Netflix maintains a strong competitive edge by offering global content variety, collaborating with key directors, and balancing quick-view movies with long-form series.

# %% [markdown]
# ## 💡9.Recommendations
#     •	Increase kids/family content to balance mature-heavy catalog.
# 	•	Expand TV Show production to boost long-term engagement.
# 	•	Invest more in regional markets like India, Japan, and South Korea.
# 	•	Strengthen partnerships with top-performing directors for consistent quality.
# 	•	Improve metadata completeness for better recommendations and search.

# %% [markdown]
# ## 🔮 10.Future Scope
#     •	Use machine learning to predict content trends and viewer preferences.
# 	•	Build a recommendation system based on genre, cast, and ratings.
# 	•	Perform sentiment analysis on descriptions or reviews.
# 	•	Forecast future content additions using time-series models.
# 	•	Cluster genres to identify similar content groups.
# 	•	Develop an interactive dashboard for deeper insights.
# 	•	Compare Netflix data with rival platforms for industry benchmarking.

# %% [markdown]
# ## ⚠ 11.Challenges Faced
#     •	Handling missing values in director, cast, and country columns.
# 	•	Converting date formats and extracting day, month, year correctly.
# 	•	Cleaning and standardizing the duration column for movies and TV shows.
# 	•	Managing inconsistent text data (multiple countries, missing fields).
# 	•	Ensuring accurate visualizations despite skewed data distribution.
# 	•	Working with a dataset lacking user ratings or view counts, limiting deeper insights.
